# %% [markdown]
# ## Deliverable 3. Create a Travel Itinerary Map.

# %%
# Dependencies and Setup
import pandas as pd
import requests
import gmaps

# Import API key
from config import g_key

# Configure gmaps
gmaps.configure(api_key=g_key)

# %%
# 1. Read the WeatherPy_vacation.csv into a DataFrame.
vacation_df = pd.read_csv("../World_Weather_Analysis/Vacation_Search/WeatherPy_Vacation.csv")
vacation_df.head()
# Out:
#    City_ID            City Country  Max Temp Weather Description      Lat  \
# 0        0         Cozumel      MX     86.07    scattered clouds  20.5083
# 1        1      Vila Velha      BR     84.15           clear sky -20.3297
# 2        2           Eskil      TR     61.92       broken clouds  38.4017
# 3        3  Guerrero Negro      MX     79.56           clear sky  27.9769
# 4        5       Busselton      AU     51.08     overcast clouds -33.6500
#
#         Lng                            Hotel Name
# 0  -86.9458  Cozumel Palace® All Inclusive Resort
# 1  -40.2925             Quality Suites Vila Velha
# 2   33.4131                    Eskil Öğretmen Evi
# 3 -114.0611          Casa Laguna, Bed & Breakfast
# 4  115.3333               Observatory Guest House

# %%
# 2. Using the template add the city name, the country code, the weather description and maximum temperature for the city.
info_box_template = """
<dl>
<dt>City</dt><dd>{City}</dd>
<dt>/Country</dt><dd>{Country}</dd>
<dt>/Current Weather</dt><dd>{Weather Description}</dd>
<dt>/Max Temp</dt><dd>{Max Temp} °F</dd>
</dl>
"""

# 3a. Get the data from each row and add it to the formatting template and store the data in a list.
hotel_info = [info_box_template.format(**row) for index, row in vacation_df.iterrows()]

# 3b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = vacation_df[["Lat", "Lng"]]

# %%
# 4a. Add a marker layer for each city to the map.
fig = gmaps.figure(center=(30.0, 31.0), zoom_level= 1.5)
marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)
fig.add_layer(marker_layer)
# 4b. Display the figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# From the map above pick 4 cities and create a vacation itinerary route to travel between the four cities. 
# 5. Create DataFrames for each city by filtering the 'vacation_df' using the loc method. 
# Hint: The starting and ending city should be the same city.

vacation_start = vacation_df.loc[vacation_df["City"] == "Roma"]
vacation_end = vacation_df.loc[vacation_df["City"] == "Roma"]
vacation_stop1 = vacation_df.loc[vacation_df["City"] == "Jamestown"]
vacation_stop2 = vacation_df.loc[vacation_df["City"] == "New Castle"] 
vacation_stop3 = vacation_df.loc[vacation_df["City"] == "Townsend"]

# %%
# 6. Get the latitude-longitude pairs as tuples from each city DataFrame using the to_numpy function and list indexing.
start = vacation_start.iloc[0,5:7].to_numpy()
end = vacation_end.iloc[0,5:7].to_numpy()
stop1 = vacation_stop1.iloc[0,5:7].to_numpy()
stop2 = vacation_stop2.iloc[0,5:7].to_numpy()
stop3 = vacation_stop3.iloc[0,5:7].to_numpy()
start
# Out:
# array([43.2128, -75.4557], dtype=object)

# %%
# 7. Create a direction layer map using the start and end latitude-longitude pairs,
# and stop1, stop2, and stop3 as the waypoints. The travel_mode should be "DRIVING", "BICYCLING", or "WALKING".
fig = gmaps.figure()
travelling_route = gmaps.directions_layer(start, end, waypoints=[stop1, stop2, stop3], travel_mode="DRIVING" or "BICYCLING" or "WALKING")
fig.add_layer(travelling_route)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# 8. To create a marker layer map between the four cities.
#  Combine the four city DataFrames into one DataFrame using the concat() function.
itinerary_df = pd.concat([vacation_start, vacation_stop1, vacation_stop2, vacation_stop3],ignore_index=True)
itinerary_df
# Out:
#     City_ID        City Country  Max Temp Weather Description      Lat  \
# 0      1811        Roma      US     74.95     overcast clouds  43.2128
# 1        26   Jamestown      US     74.17           clear sky  42.0970
# 2        28   Jamestown      US     74.17           clear sky  42.0970
# 3       103   Jamestown      US     74.17           clear sky  42.0970
# 4       391   Jamestown      US     74.17           clear sky  42.0970
# 5       493   Jamestown      US     74.17           clear sky  42.0970
# 6       562   Jamestown      US     74.17           clear sky  42.0970
# 7       763   Jamestown      US     74.17           clear sky  42.0970
# 8       772   Jamestown      US     74.17           clear sky  42.0970
# 9       777   Jamestown      US     74.17           clear sky  42.0970
# 10      778   Jamestown      US     74.17           clear sky  42.0970
# 11      816   Jamestown      US     74.17           clear sky  42.0970
# 12      917   Jamestown      US     74.17           clear sky  42.0970
# 13     1000   Jamestown      US     74.17           clear sky  42.0970
# 14     1001   Jamestown      US     74.17           clear sky  42.0970
# 15     1054   Jamestown      US     74.17           clear sky  42.0970
# 16     1275   Jamestown      US     74.17           clear sky  42.0970
# 17     1624   Jamestown      US     74.17           clear sky  42.0970
# 18     1680   Jamestown      US     74.17           clear sky  42.0970
# 19     1756   Jamestown      US     74.17           clear sky  42.0970
# 20     1078  New Castle      US     74.48           clear sky  41.0037
# 21      296    Townsend      US     77.22    scattered clouds  39.3951
#
#         Lng                                   Hotel Name
# 0  -75.4557                      Wingate By Wyndham Rome
# 1  -79.2353               Hampton Inn & Suites Jamestown
# 2  -79.2353               Hampton Inn & Suites Jamestown
# 3  -79.2353               Hampton Inn & Suites Jamestown
# 4  -79.2353               Hampton Inn & Suites Jamestown
# 5  -79.2353               Hampton Inn & Suites Jamestown
# 6  -79.2353               Hampton Inn & Suites Jamestown
# 7  -79.2353               Hampton Inn & Suites Jamestown
# 8  -79.2353               Hampton Inn & Suites Jamestown
# 9  -79.2353               Hampton Inn & Suites Jamestown
# 10 -79.2353               Hampton Inn & Suites Jamestown
# 11 -79.2353               Hampton Inn & Suites Jamestown
# 12 -79.2353               Hampton Inn & Suites Jamestown
# 13 -79.2353               Hampton Inn & Suites Jamestown
# 14 -79.2353               Hampton Inn & Suites Jamestown
# 15 -79.2353               Hampton Inn & Suites Jamestown
# 16 -79.2353               Hampton Inn & Suites Jamestown
# 17 -79.2353               Hampton Inn & Suites Jamestown
# 18 -79.2353               Hampton Inn & Suites Jamestown
# 19 -79.2353               Hampton Inn & Suites Jamestown
# 20 -80.3470              Hampton Inn & Suites New Castle
# 21 -75.6916  Frederick Lodge Manufactured Home Community

# %%
# 9 Using the template add city name, the country code, the weather description and maximum temperature for the city. 
info_box_template = """
<dl>
<dt>City</dt><dd>{City}</dd>
<dt>/Country</dt><dd>{Country}</dd>
<dt>/Current Weather</dt><dd>{Weather Description}</dd>
<dt>/Max Temp</dt><dd>{Max Temp} °F</dd>
</dl>
"""

# 10a Get the data from each row and add it to the formatting template and store the data in a list.
hotel_info = [info_box_template.format(**row) for index, row in itinerary_df.iterrows()]

# 10b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = itinerary_df[["Lat", "Lng"]]

# %%
# 11a. Add a marker layer for each city to the map.
fig= gmaps.figure()
marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)
fig.add_layer(marker_layer)
# 11b. Display the figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
